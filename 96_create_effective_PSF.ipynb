# %%
import numpy as np
import matplotlib.pyplot as plt

from lightkurve import search_targetpixelfile
from lightkurve import KeplerTargetPixelFile

from photutils.psf import IntegratedGaussianPRF, DAOGroup
from photutils.background import MMMBackground, MADStdBackgroundRMS
from photutils.psf import BasicPSFPhotometry

from photutils.detection import find_peaks
from photutils.psf import EPSFStar, EPSFStars, EPSFBuilder

from astropy.modeling.fitting import LevMarLSQFitter, LinearLSQFitter
from astropy.stats import gaussian_sigma_to_fwhm
from astropy.table import Table

# %%
from copy import deepcopy
import pickle

# %%
with open('data/single_targets_channel29_c07.txt', 'r') as f:
    stars = []
    for line in f:
        print(line)
        TPF = search_targetpixelfile(line).download()
        image = TPF.flux[index,:,:]
        peak = find_peaks(image,box_size=5,npeaks=1,threshold=0.5*np.nanmean(image)).to_pandas().iloc[0]
        stars.append(EPSFStar(image,cutout_center=(peak.x_peak,peak.y_peak)))
        print(len(stars))
        pickle.dump(stars, open( "data/stars29.p", "wb" ))
# Out:
# 218843971
#
# 1
# 218856189
#
# 2
# 218864892
#
# 3
# 218884924
#
# 4
# 218910907
#
# 5
# 218914535
#
# 6
# 218916923
#
# 7
# 218918826
#
# 8
# 218933140
#
# 9
# 218942118
#
# 10
# 218946688
#
# 11
# 218952188
#
# 12
# 218963431
#
# 13
# 218965745
#
# 14
# 218967024
#
# 15
# 218971693
#
# 16
# 218979353
#
# 17
# 218985855
#
# 18
# 218986084
#
# 19
# 218986703
#
# 20
# 218987509
#
# 21
# 218988659
#
# 22
# 218989460
#
# 23
# 218989655
#
# 24
# 218990306
#
# 25
# 218990401
#
# 26
# 218994179
#
# 27
# 218996955
#
# 28
# 218998314
#
# 29
# 219000485
#
# 30
# 219004362
#
# 31
# 219005894
#
# 32
# 219011883
#
# 33
# 219013024
#
# 34
# 219013697
#
# 35
# 219015324
#
# 36
# 219016116
#
# 37
# 219020833
#
# 38
# 219026085
#
# 39
# 219026212
#
# 40
# 219031467
#
# 41
# 219034422
#
# 42
# 219034971
#
# 43
# 219035181
#
# 44
# 219037633
#
# 45
# 219039523
#
# 46
# 219039609
#
# 47
# 219039768
#
# 48
# 219039911
#
# 49
# 219042731
#
# 50
# 219053763
#
# 51
# 219055784
#
# 52
# 219056975
#
# 53
# 219057253
#
# 54
# 219058449
#
# 55
# 219060112
#
# 56
# 219060305
#
# 57
# 219062123
#
# 58
# 219064989
#
# 59
# 219070154
#
# 60
# 219072616
#
# 61
# 219073502
#
# 62
# 219079131
#
# 63
# 219080844
#
# 64
# 219083481
#
# 65
# 219088599
#
# 66
# 219092257
#
# 67
# 219096230
#
# 68
# 219098524
#
# 69
# 219100036
#
# 70
# 219101557
#
# 71
# 219101607
#
# 72
# 219103422
#
# 73
# 219104619
#
# 74
# 219110376
#
# 75
# 219111248
#
# 76
# 219115432
#
# 77
# 219115850
#
# 78
# 219118006
#
# 79
# 219121053
#
# 80
# 219122150
#
# 81
# 219127243
#
# 82
# 219128477
#
# 83
# 219129635
#
# 84
# 219129730
#
# 85
# 219134004
#
# 86
# 219136507
#
# 87
# 219139103
#
# 88
# 219142554
#
# 89
# 219142601
#
# 90
# 219142705
#
# 91
# 219144458
#
# 92
# 219144510
#
# 93
# 219145872
#
# 94
# 219146623
#
# 95
# 219147400
#
# 96
# 219149032
#
# 97
# 219151382
#
# 98
# 219153224
#
# 99
# 219154297
#
# 100
# 219154868
#
# 101
# 219155665
#
# 102
# 219156219
#
# 103
# 219158206
#
# 104
# 219158878
#
# 105
# 219160525
#
# 106
# 219161541
#
# 107
# 219161742
#
# 108
# 219164660
#
# 109
# 219164853
#
# 110
# 219169489
#
# 111
# 219171702
#
# 112
# 219174407
#
# 113
# 219180038
#
# 114
# 219181570
#
# 115
# 219182144
#
# 116
# 219183715
#
# 117
# 219185362
#
# 118
# 219194184
#
# 119
# 219196000
#
# 120
# 219196903
#
# 121
# 219197807
#
# 122
# 219198781
#
# 123
# 219202043
#
# 124
# 219203067
#
# 125
# 219203743
#
# 126
# 219205024
#
# 127
# 219205477
#
# 128
# 219205838
#
# 129
# 219208969
#
# 130
# 219211909
#
# 131
# 219215728
#
# 132
# 219215967
#
# 133
# 219216013
#
# 134
# 219217553
#
# 135
# 219217598
#
# 136
# 219221064
#
# 137
# 219223026
#
# 138
# 219224668
#
# 139
# 219225128
#
# 140
# 219225331
#
# 141
# 219225699
#
# 142
# 219227450
#
# 143
# 219227801
#
# 144
# 219229880
#
# 145
# 219232086
#
# 146
# 219233227
#
# 147
# 219234319
#
# 148
# 219236129
#
# 149
# 219236197
#
# 150
# 219236302
#
# 151
# 219236618
#
# 152
# 219236972
#
# 153
# 219238088
#
# 154
# 219238231
#
# 155
# 219239645
#
# 156
# 219239754
#
# 157
# 219240689
#
# 158
# 219245212
#
# 159
# 219245901
#
# 160
# 219246028
#
# 161
# 219246745
#
# 162
# 219249448
#
# 163
# 219255925
#
# 164
# 219256928
#
# 165
# 219259678
#
# 166
# 219260763
#
# 167
# 219268670
#
# 168
# 219273189
#
# 169
# 219275508
#
# 170
# 219275512
#
# 171
# 219276784
#
# 172
# 219278646
#
# 173
# 219280010
#
# 174
# 219280381
#
# 175
# 219283637
#
# 176
# 219285521
#
# 177
# 219287548
#
# 178
# 219294646
#
# 179
# 219295170
#
# 180
# 219295624
#
# 181
# 219296218
#
# 182
# 219296488
#
# 183
# 219296525
#
# 184
# 219296766
#
# 185
# 219297228
#
# 186
# 219299875
#
# 187
# 219301051
#
# 188
# 219301444
#
# 189
# 219302088
#
# 190
# 219302572
#
# 191
# 219303488
#
# 192
# 219303757
#
# 193
# 219305275
#
# 194
# 219306354
#
# 195
# 219307424
#
# 196
# 219308521
#
# 197
# 219310397
#
# 198
# 219312741
#
# 199
# 219314371
#
# 200
# 219315832
#
# 201
# 219316493
#
# 202
# 219317063
#
# 203
# 219317087
#
# 204
# 219317665
#
# 205
# 219319428
#
# 206
# 219321875
#
# 207
# 219322869
#
# 208
# 219324024
#
# 209
# 219327704
#
# 210
# 219328980
#
# 211
# 219330454
#
# 212
# 219331767
#
# 213
# 219333796
#
# 214
# 219333882
#
# 215
# 219339919
#
# 216
# 219340623
#
# 217
# 219341906
#
# 218
# 219342005
#
# 219
# 219342033
#
# 220
# 219343839
#
# 221
# 219346000
#
# 222
# 219346771
#
# 223
# 219347013
#
# 224
# 219348224
#
# 225
# 219350938
#
# 226
# 219353144
#
# 227
# 219358294
#
# 228
# 219359014
#
# 229
# 219362154
#
# 230
# 219364586
#
# 231
# 219365661
#
# 232
# 219366731
#
# 233
# 219367259
#
# 234
# 219368292
#
# 235
# 219368810
#
# 236
# 219370908
#
# 237
# 219372857
#
# 238
# 219373500
#
# 239
# 219373920
#
# 240
# 219378499
#
# 241
# 219379594
#
# 242
# 219379881
#
# 243
# 219386608
#
# 244
# 219388013
#
# 245
# 219388192
#
# 246
# 219388809
#
# 247
# 219389230
#
# 248
# 219391524
#
# 249
# 219393078
#
# 250
# 219393192
#
# 251
# 219394846
#
# 252
# 219395056
#
# 253
# 219396051
#
# 254
# 219396544
#
# 255
# 219404735
#
# 256
# 219405697
#
# 257
# 219406637
#
# 258
# 219407502
#
# 259
# 219410939
#
# 260
# 219416327
#
# 261
# 219422386
#
# 262
# 219423944
#
# 263
# 219426848
#
# 264
# 219429721
#
# 265
# 219438587
#
# 266
# 219442206
#
# 267
# 219443345
#
# 268
# 219449064
#
# 269
# 219449294
#
# 270
# 219458326
#
# 271
# 219460213
# 272

# %%
stars = pickle.load(open("data/stars29.p", "rb"))
stars = EPSFStars(stars)
epsfb = EPSFBuilder(oversampling=4,shape=35)
epsf, fitted_stars = epsfb(stars)
# Out:
# PROGRESS: iteration 1 (of max 10) [? s/iter]
# WARNING: The star at (8.0, 9.0) cannot be fit because its fitting region extends beyond the star cutout image. [photutils.psf.epsf]
# WARNING: The star at (5.0, 0.0) cannot be fit because its fitting region extends beyond the star cutout image. [photutils.psf.epsf]
# WARNING: The star at (0.0, 3.0) cannot be fit because its fitting region extends beyond the star cutout image. [photutils.psf.epsf]
# WARNING: The star at (0.0, 5.0) cannot be fit because its fitting region extends beyond the star cutout image. [photutils.psf.epsf]
# WARNING: The star at (8.0, 7.0) cannot be fit because its fitting region extends beyond the star cutout image. [photutils.psf.epsf]
# WARNING: The star at (6.0, 7.0) cannot be fit because its fitting region extends beyond the star cutout image. [photutils.psf.epsf]
# WARNING: The star at (3.0, 9.0) cannot be fit because its fitting region extends beyond the star cutout image. [photutils.psf.epsf]
# WARNING: The star at (8.0, 6.0) cannot be fit because its fitting region extends beyond the star cutout image. [photutils.psf.epsf]
# WARNING: The star at (5.0, 5.0) cannot be fit because its fitting region extends beyond the star cutout image. [photutils.psf.epsf]
# WARNING: The star at (4.0, 1.0) cannot be fit because its fitting region extends beyond the star cutout image. [photutils.psf.epsf]
# WARNING: The star at (2.0, 10.0) cannot be fit because its fitting region extends beyond the star cutout image. [photutils.psf.epsf]
# WARNING: The star at (9.0, 4.0) cannot be fit because its fitting region extends beyond the star cutout image. [photutils.psf.epsf]
# WARNING: The star at (0.0, 1.0) cannot be fit because its fitting region extends beyond the star cutout image. [photutils.psf.epsf]
# WARNING: The star at (0.0, 0.0) cannot be fit because its fitting region extends beyond the star cutout image. [photutils.psf.epsf]
# WARNING: The star at (3.0, 0.0) cannot be fit because its fitting region extends beyond the star cutout image. [photutils.psf.epsf]
# WARNING: The star at (9.0, 3.0) cannot be fit because its fitting region extends beyond the star cutout image. [photutils.psf.epsf]
# WARNING: The star at (4.0, 5.0) cannot be fit because its fitting region extends beyond the star cutout image. [photutils.psf.epsf]
# WARNING: The star at (9.0, 8.0) cannot be fit because its fitting region extends beyond the star cutout image. [photutils.psf.epsf]
# WARNING: The star at (6.0, 1.0) cannot be fit because its fitting region extends beyond the star cutout image. [photutils.psf.epsf]
# WARNING: The star at (6.0, 9.0) cannot be fit because its fitting region extends beyond the star cutout image. [photutils.psf.epsf]
# WARNING: The star at (0.0, 2.0) cannot be fit because its fitting region extends beyond the star cutout image. [photutils.psf.epsf]
# PROGRESS: iteration 2 (of max 10) [3.0 s/iter]
# WARNING: The star at (8.0, 9.0) cannot be fit because its fitting region extends beyond the star cutout image. [photutils.psf.epsf]
# WARNING: The star at (5.0, 0.0) cannot be fit because its fitting region extends beyond the star cutout image. [photutils.psf.epsf]
# WARNING: The star at (0.0, 3.0) cannot be fit because its fitting region extends beyond the star cutout image. [photutils.psf.epsf]
# WARNING: The star at (0.0, 5.0) cannot be fit because its fitting region extends beyond the star cutout image. [photutils.psf.epsf]
# WARNING: The star at (8.0, 7.0) cannot be fit because its fitting region extends beyond the star cutout image. [photutils.psf.epsf]
# WARNING: The star at (6.0, 7.0) cannot be fit because its fitting region extends beyond the star cutout image. [photutils.psf.epsf]
# WARNING: The star at (3.0, 9.0) cannot be fit because its fitting region extends beyond the star cutout image. [photutils.psf.epsf]
# WARNING: The star at (8.0, 6.0) cannot be fit because its fitting region extends beyond the star cutout image. [photutils.psf.epsf]
# WARNING: The star at (5.0, 5.0) cannot be fit because its fitting region extends beyond the star cutout image. [photutils.psf.epsf]
# WARNING: The star at (4.0, 1.0) cannot be fit because its fitting region extends beyond the star cutout image. [photutils.psf.epsf]
# WARNING: The star at (2.0, 10.0) cannot be fit because its fitting region extends beyond the star cutout image. [photutils.psf.epsf]
# WARNING: The star at (9.0, 4.0) cannot be fit because its fitting region extends beyond the star cutout image. [photutils.psf.epsf]
# WARNING: The star at (0.0, 1.0) cannot be fit because its fitting region extends beyond the star cutout image. [photutils.psf.epsf]
# WARNING: The star at (0.0, 0.0) cannot be fit because its fitting region extends beyond the star cutout image. [photutils.psf.epsf]
# WARNING: The star at (3.0, 0.0) cannot be fit because its fitting region extends beyond the star cutout image. [photutils.psf.epsf]
# WARNING: The star at (9.0, 3.0) cannot be fit because its fitting region extends beyond the star cutout image. [photutils.psf.epsf]
# WARNING: The star at (4.0, 5.0) cannot be fit because its fitting region extends beyond the star cutout image. [photutils.psf.epsf]
# WARNING: The star at (9.0, 8.0) cannot be fit because its fitting region extends beyond the star cutout image. [photutils.psf.epsf]
# WARNING: The star at (6.0, 1.0) cannot be fit because its fitting region extends beyond the star cutout image. [photutils.psf.epsf]
# WARNING: The star at (6.0, 9.0) cannot be fit because its fitting region extends beyond the star cutout image. [photutils.psf.epsf]
# WARNING: The star at (0.0, 2.0) cannot be fit because its fitting region extends beyond the star cutout image. [photutils.psf.epsf]
# PROGRESS: iteration 3 (of max 10) [2.2 s/iter]
# WARNING: The star at (8.0, 9.0) cannot be fit because its fitting region extends beyond the star cutout image. [photutils.psf.epsf]
# WARNING: The star at (5.0, 0.0) cannot be fit because its fitting region extends beyond the star cutout image. [photutils.psf.epsf]
# WARNING: The star at (0.0, 3.0) cannot be fit because its fitting region extends beyond the star cutout image. [photutils.psf.epsf]
# WARNING: The star at (0.0, 5.0) cannot be fit because its fitting region extends beyond the star cutout image. [photutils.psf.epsf]
# WARNING: The star at (8.0, 7.0) cannot be fit because its fitting region extends beyond the star cutout image. [photutils.psf.epsf]
# WARNING: The star at (6.0, 7.0) cannot be fit because its fitting region extends beyond the star cutout image. [photutils.psf.epsf]
# WARNING: The star at (3.0, 9.0) cannot be fit because its fitting region extends beyond the star cutout image. [photutils.psf.epsf]
# WARNING: The star at (8.0, 6.0) cannot be fit because its fitting region extends beyond the star cutout image. [photutils.psf.epsf]
# WARNING: The star at (5.0, 5.0) cannot be fit because its fitting region extends beyond the star cutout image. [photutils.psf.epsf]
# WARNING: The star at (4.0, 1.0) cannot be fit because its fitting region extends beyond the star cutout image. [photutils.psf.epsf]
# WARNING: The star at (2.0, 10.0) cannot be fit because its fitting region extends beyond the star cutout image. [photutils.psf.epsf]
# WARNING: The star at (9.0, 4.0) cannot be fit because its fitting region extends beyond the star cutout image. [photutils.psf.epsf]
# WARNING: The star at (0.0, 1.0) cannot be fit because its fitting region extends beyond the star cutout image. [photutils.psf.epsf]
# WARNING: The star at (0.0, 0.0) cannot be fit because its fitting region extends beyond the star cutout image. [photutils.psf.epsf]
# WARNING: The star at (3.0, 0.0) cannot be fit because its fitting region extends beyond the star cutout image. [photutils.psf.epsf]
# WARNING: The star at (9.0, 3.0) cannot be fit because its fitting region extends beyond the star cutout image. [photutils.psf.epsf]
# WARNING: The star at (4.0, 5.0) cannot be fit because its fitting region extends beyond the star cutout image. [photutils.psf.epsf]
# WARNING: The star at (9.0, 8.0) cannot be fit because its fitting region extends beyond the star cutout image. [photutils.psf.epsf]
# WARNING: The star at (6.0, 1.0) cannot be fit because its fitting region extends beyond the star cutout image. [photutils.psf.epsf]
# WARNING: The star at (6.0, 9.0) cannot be fit because its fitting region extends beyond the star cutout image. [photutils.psf.epsf]
# WARNING: The star at (0.0, 2.0) cannot be fit because its fitting region extends beyond the star cutout image. [photutils.psf.epsf]
# PROGRESS: iteration 4 (of max 10) [2.2 s/iter]
# WARNING: The star at (8.0, 9.0) cannot be fit because its fitting region extends beyond the star cutout image. [photutils.psf.epsf]
# WARNING: The star at (5.0, 0.0) cannot be fit because its fitting region extends beyond the star cutout image. [photutils.psf.epsf]
# WARNING: The star at (0.0, 3.0) cannot be fit because its fitting region extends beyond the star cutout image. [photutils.psf.epsf]
# WARNING: The star at (0.0, 5.0) cannot be fit because its fitting region extends beyond the star cutout image. [photutils.psf.epsf]
# WARNING: The star at (8.0, 7.0) cannot be fit because its fitting region extends beyond the star cutout image. [photutils.psf.epsf]
# WARNING: The star at (6.0, 7.0) cannot be fit because its fitting region extends beyond the star cutout image. [photutils.psf.epsf]
# WARNING: The star at (3.0, 9.0) cannot be fit because its fitting region extends beyond the star cutout image. [photutils.psf.epsf]
# WARNING: The star at (8.0, 6.0) cannot be fit because its fitting region extends beyond the star cutout image. [photutils.psf.epsf]
# WARNING: The star at (5.0, 5.0) cannot be fit because its fitting region extends beyond the star cutout image. [photutils.psf.epsf]
# WARNING: The star at (4.0, 1.0) cannot be fit because its fitting region extends beyond the star cutout image. [photutils.psf.epsf]
# WARNING: The star at (2.0, 10.0) cannot be fit because its fitting region extends beyond the star cutout image. [photutils.psf.epsf]
# WARNING: The star at (9.0, 4.0) cannot be fit because its fitting region extends beyond the star cutout image. [photutils.psf.epsf]
# WARNING: The star at (0.0, 1.0) cannot be fit because its fitting region extends beyond the star cutout image. [photutils.psf.epsf]
# WARNING: The star at (0.0, 0.0) cannot be fit because its fitting region extends beyond the star cutout image. [photutils.psf.epsf]
# WARNING: The star at (3.0, 0.0) cannot be fit because its fitting region extends beyond the star cutout image. [photutils.psf.epsf]
# WARNING: The star at (9.0, 3.0) cannot be fit because its fitting region extends beyond the star cutout image. [photutils.psf.epsf]
# WARNING: The star at (4.0, 5.0) cannot be fit because its fitting region extends beyond the star cutout image. [photutils.psf.epsf]
# WARNING: The star at (9.0, 8.0) cannot be fit because its fitting region extends beyond the star cutout image. [photutils.psf.epsf]
# WARNING: The star at (6.0, 1.0) cannot be fit because its fitting region extends beyond the star cutout image. [photutils.psf.epsf]
# WARNING: The star at (6.0, 9.0) cannot be fit because its fitting region extends beyond the star cutout image. [photutils.psf.epsf]
# WARNING: The star at (0.0, 2.0) cannot be fit because its fitting region extends beyond the star cutout image. [photutils.psf.epsf]
# PROGRESS: iteration 5 (of max 10) [2.0 s/iter]
# WARNING: The star at (8.0, 9.0) cannot be fit because its fitting region extends beyond the star cutout image. [photutils.psf.epsf]
# WARNING: The star at (5.0, 0.0) cannot be fit because its fitting region extends beyond the star cutout image. [photutils.psf.epsf]
# WARNING: The star at (0.0, 3.0) cannot be fit because its fitting region extends beyond the star cutout image. [photutils.psf.epsf]
# WARNING: The star at (0.0, 5.0) cannot be fit because its fitting region extends beyond the star cutout image. [photutils.psf.epsf]
# WARNING: The star at (8.0, 7.0) cannot be fit because its fitting region extends beyond the star cutout image. [photutils.psf.epsf]
# WARNING: The star at (6.0, 7.0) cannot be fit because its fitting region extends beyond the star cutout image. [photutils.psf.epsf]
# WARNING: The star at (3.0, 9.0) cannot be fit because its fitting region extends beyond the star cutout image. [photutils.psf.epsf]
# WARNING: The star at (8.0, 6.0) cannot be fit because its fitting region extends beyond the star cutout image. [photutils.psf.epsf]
# WARNING: The star at (5.0, 5.0) cannot be fit because its fitting region extends beyond the star cutout image. [photutils.psf.epsf]
# WARNING: The star at (4.0, 1.0) cannot be fit because its fitting region extends beyond the star cutout image. [photutils.psf.epsf]
# WARNING: The star at (2.0, 10.0) cannot be fit because its fitting region extends beyond the star cutout image. [photutils.psf.epsf]
# WARNING: The star at (9.0, 4.0) cannot be fit because its fitting region extends beyond the star cutout image. [photutils.psf.epsf]
# WARNING: The star at (0.0, 1.0) cannot be fit because its fitting region extends beyond the star cutout image. [photutils.psf.epsf]
# WARNING: The star at (0.0, 0.0) cannot be fit because its fitting region extends beyond the star cutout image. [photutils.psf.epsf]
# WARNING: The star at (3.0, 0.0) cannot be fit because its fitting region extends beyond the star cutout image. [photutils.psf.epsf]
# WARNING: The star at (9.0, 3.0) cannot be fit because its fitting region extends beyond the star cutout image. [photutils.psf.epsf]
# WARNING: The star at (4.0, 5.0) cannot be fit because its fitting region extends beyond the star cutout image. [photutils.psf.epsf]
# WARNING: The star at (9.0, 8.0) cannot be fit because its fitting region extends beyond the star cutout image. [photutils.psf.epsf]
# WARNING: The star at (6.0, 1.0) cannot be fit because its fitting region extends beyond the star cutout image. [photutils.psf.epsf]
# WARNING: The star at (6.0, 9.0) cannot be fit because its fitting region extends beyond the star cutout image. [photutils.psf.epsf]
# WARNING: The star at (0.0, 2.0) cannot be fit because its fitting region extends beyond the star cutout image. [photutils.psf.epsf]
# PROGRESS: iteration 6 (of max 10) [1.8 s/iter]
# WARNING: The star at (8.0, 9.0) cannot be fit because its fitting region extends beyond the star cutout image. [photutils.psf.epsf]
# WARNING: The star at (5.0, 0.0) cannot be fit because its fitting region extends beyond the star cutout image. [photutils.psf.epsf]
# WARNING: The star at (0.0, 3.0) cannot be fit because its fitting region extends beyond the star cutout image. [photutils.psf.epsf]
# WARNING: The star at (0.0, 5.0) cannot be fit because its fitting region extends beyond the star cutout image. [photutils.psf.epsf]
# WARNING: The star at (8.0, 7.0) cannot be fit because its fitting region extends beyond the star cutout image. [photutils.psf.epsf]
# WARNING: The star at (6.0, 7.0) cannot be fit because its fitting region extends beyond the star cutout image. [photutils.psf.epsf]
# WARNING: The star at (3.0, 9.0) cannot be fit because its fitting region extends beyond the star cutout image. [photutils.psf.epsf]
# WARNING: The star at (8.0, 6.0) cannot be fit because its fitting region extends beyond the star cutout image. [photutils.psf.epsf]
# WARNING: The star at (5.0, 5.0) cannot be fit because its fitting region extends beyond the star cutout image. [photutils.psf.epsf]
# WARNING: The star at (4.0, 1.0) cannot be fit because its fitting region extends beyond the star cutout image. [photutils.psf.epsf]
# WARNING: The star at (2.0, 10.0) cannot be fit because its fitting region extends beyond the star cutout image. [photutils.psf.epsf]
# WARNING: The star at (9.0, 4.0) cannot be fit because its fitting region extends beyond the star cutout image. [photutils.psf.epsf]
# WARNING: The star at (0.0, 1.0) cannot be fit because its fitting region extends beyond the star cutout image. [photutils.psf.epsf]
# WARNING: The star at (0.0, 0.0) cannot be fit because its fitting region extends beyond the star cutout image. [photutils.psf.epsf]
# WARNING: The star at (3.0, 0.0) cannot be fit because its fitting region extends beyond the star cutout image. [photutils.psf.epsf]
# WARNING: The star at (9.0, 3.0) cannot be fit because its fitting region extends beyond the star cutout image. [photutils.psf.epsf]
# WARNING: The star at (4.0, 5.0) cannot be fit because its fitting region extends beyond the star cutout image. [photutils.psf.epsf]
# WARNING: The star at (9.0, 8.0) cannot be fit because its fitting region extends beyond the star cutout image. [photutils.psf.epsf]
# WARNING: The star at (6.0, 1.0) cannot be fit because its fitting region extends beyond the star cutout image. [photutils.psf.epsf]
# WARNING: The star at (6.0, 9.0) cannot be fit because its fitting region extends beyond the star cutout image. [photutils.psf.epsf]
# WARNING: The star at (0.0, 2.0) cannot be fit because its fitting region extends beyond the star cutout image. [photutils.psf.epsf]
# PROGRESS: iteration 7 (of max 10) [2.0 s/iter]
# WARNING: The star at (8.0, 9.0) cannot be fit because its fitting region extends beyond the star cutout image. [photutils.psf.epsf]
# WARNING: The star at (5.0, 0.0) cannot be fit because its fitting region extends beyond the star cutout image. [photutils.psf.epsf]
# WARNING: The star at (0.0, 3.0) cannot be fit because its fitting region extends beyond the star cutout image. [photutils.psf.epsf]
# WARNING: The star at (0.0, 5.0) cannot be fit because its fitting region extends beyond the star cutout image. [photutils.psf.epsf]
# WARNING: The star at (8.0, 7.0) cannot be fit because its fitting region extends beyond the star cutout image. [photutils.psf.epsf]
# WARNING: The star at (6.0, 7.0) cannot be fit because its fitting region extends beyond the star cutout image. [photutils.psf.epsf]
# WARNING: The star at (3.0, 9.0) cannot be fit because its fitting region extends beyond the star cutout image. [photutils.psf.epsf]
# WARNING: The star at (8.0, 6.0) cannot be fit because its fitting region extends beyond the star cutout image. [photutils.psf.epsf]
# WARNING: The star at (5.0, 5.0) cannot be fit because its fitting region extends beyond the star cutout image. [photutils.psf.epsf]
# WARNING: The star at (4.0, 1.0) cannot be fit because its fitting region extends beyond the star cutout image. [photutils.psf.epsf]
# WARNING: The star at (2.0, 10.0) cannot be fit because its fitting region extends beyond the star cutout image. [photutils.psf.epsf]
# WARNING: The star at (9.0, 4.0) cannot be fit because its fitting region extends beyond the star cutout image. [photutils.psf.epsf]
# WARNING: The star at (0.0, 1.0) cannot be fit because its fitting region extends beyond the star cutout image. [photutils.psf.epsf]
# WARNING: The star at (0.0, 0.0) cannot be fit because its fitting region extends beyond the star cutout image. [photutils.psf.epsf]
# WARNING: The star at (3.0, 0.0) cannot be fit because its fitting region extends beyond the star cutout image. [photutils.psf.epsf]
# WARNING: The star at (9.0, 3.0) cannot be fit because its fitting region extends beyond the star cutout image. [photutils.psf.epsf]
# WARNING: The star at (4.0, 5.0) cannot be fit because its fitting region extends beyond the star cutout image. [photutils.psf.epsf]
# WARNING: The star at (9.0, 8.0) cannot be fit because its fitting region extends beyond the star cutout image. [photutils.psf.epsf]
# WARNING: The star at (6.0, 1.0) cannot be fit because its fitting region extends beyond the star cutout image. [photutils.psf.epsf]
# WARNING: The star at (6.0, 9.0) cannot be fit because its fitting region extends beyond the star cutout image. [photutils.psf.epsf]
# WARNING: The star at (0.0, 2.0) cannot be fit because its fitting region extends beyond the star cutout image. [photutils.psf.epsf]
# PROGRESS: iteration 8 (of max 10) [2.1 s/iter]
# WARNING: The star at (8.0, 9.0) cannot be fit because its fitting region extends beyond the star cutout image. [photutils.psf.epsf]
# WARNING: The star at (5.0, 0.0) cannot be fit because its fitting region extends beyond the star cutout image. [photutils.psf.epsf]
# WARNING: The star at (0.0, 3.0) cannot be fit because its fitting region extends beyond the star cutout image. [photutils.psf.epsf]
# WARNING: The star at (0.0, 5.0) cannot be fit because its fitting region extends beyond the star cutout image. [photutils.psf.epsf]
# WARNING: The star at (8.0, 7.0) cannot be fit because its fitting region extends beyond the star cutout image. [photutils.psf.epsf]
# WARNING: The star at (6.0, 7.0) cannot be fit because its fitting region extends beyond the star cutout image. [photutils.psf.epsf]
# WARNING: The star at (3.0, 9.0) cannot be fit because its fitting region extends beyond the star cutout image. [photutils.psf.epsf]
# WARNING: The star at (8.0, 6.0) cannot be fit because its fitting region extends beyond the star cutout image. [photutils.psf.epsf]
# WARNING: The star at (5.0, 5.0) cannot be fit because its fitting region extends beyond the star cutout image. [photutils.psf.epsf]
# WARNING: The star at (4.0, 1.0) cannot be fit because its fitting region extends beyond the star cutout image. [photutils.psf.epsf]
# WARNING: The star at (2.0, 10.0) cannot be fit because its fitting region extends beyond the star cutout image. [photutils.psf.epsf]
# WARNING: The star at (9.0, 4.0) cannot be fit because its fitting region extends beyond the star cutout image. [photutils.psf.epsf]
# WARNING: The star at (0.0, 1.0) cannot be fit because its fitting region extends beyond the star cutout image. [photutils.psf.epsf]
# WARNING: The star at (0.0, 0.0) cannot be fit because its fitting region extends beyond the star cutout image. [photutils.psf.epsf]
# WARNING: The star at (3.0, 0.0) cannot be fit because its fitting region extends beyond the star cutout image. [photutils.psf.epsf]
# WARNING: The star at (9.0, 3.0) cannot be fit because its fitting region extends beyond the star cutout image. [photutils.psf.epsf]
# WARNING: The star at (4.0, 5.0) cannot be fit because its fitting region extends beyond the star cutout image. [photutils.psf.epsf]
# WARNING: The star at (9.0, 8.0) cannot be fit because its fitting region extends beyond the star cutout image. [photutils.psf.epsf]
# WARNING: The star at (6.0, 1.0) cannot be fit because its fitting region extends beyond the star cutout image. [photutils.psf.epsf]
# WARNING: The star at (6.0, 9.0) cannot be fit because its fitting region extends beyond the star cutout image. [photutils.psf.epsf]
# WARNING: The star at (0.0, 2.0) cannot be fit because its fitting region extends beyond the star cutout image. [photutils.psf.epsf]
# PROGRESS: iteration 9 (of max 10) [1.9 s/iter]
# WARNING: The star at (8.0, 9.0) cannot be fit because its fitting region extends beyond the star cutout image. [photutils.psf.epsf]
# WARNING: The star at (5.0, 0.0) cannot be fit because its fitting region extends beyond the star cutout image. [photutils.psf.epsf]
# WARNING: The star at (0.0, 3.0) cannot be fit because its fitting region extends beyond the star cutout image. [photutils.psf.epsf]
# WARNING: The star at (0.0, 5.0) cannot be fit because its fitting region extends beyond the star cutout image. [photutils.psf.epsf]
# WARNING: The star at (8.0, 7.0) cannot be fit because its fitting region extends beyond the star cutout image. [photutils.psf.epsf]
# WARNING: The star at (6.0, 7.0) cannot be fit because its fitting region extends beyond the star cutout image. [photutils.psf.epsf]
# WARNING: The star at (3.0, 9.0) cannot be fit because its fitting region extends beyond the star cutout image. [photutils.psf.epsf]
# WARNING: The star at (8.0, 6.0) cannot be fit because its fitting region extends beyond the star cutout image. [photutils.psf.epsf]
# WARNING: The star at (5.0, 5.0) cannot be fit because its fitting region extends beyond the star cutout image. [photutils.psf.epsf]
# WARNING: The star at (4.0, 1.0) cannot be fit because its fitting region extends beyond the star cutout image. [photutils.psf.epsf]
# WARNING: The star at (2.0, 10.0) cannot be fit because its fitting region extends beyond the star cutout image. [photutils.psf.epsf]
# WARNING: The star at (9.0, 4.0) cannot be fit because its fitting region extends beyond the star cutout image. [photutils.psf.epsf]
# WARNING: The star at (0.0, 1.0) cannot be fit because its fitting region extends beyond the star cutout image. [photutils.psf.epsf]
# WARNING: The star at (0.0, 0.0) cannot be fit because its fitting region extends beyond the star cutout image. [photutils.psf.epsf]
# WARNING: The star at (3.0, 0.0) cannot be fit because its fitting region extends beyond the star cutout image. [photutils.psf.epsf]
# WARNING: The star at (9.0, 3.0) cannot be fit because its fitting region extends beyond the star cutout image. [photutils.psf.epsf]
# WARNING: The star at (4.0, 5.0) cannot be fit because its fitting region extends beyond the star cutout image. [photutils.psf.epsf]
# WARNING: The star at (9.0, 8.0) cannot be fit because its fitting region extends beyond the star cutout image. [photutils.psf.epsf]
# WARNING: The star at (6.0, 1.0) cannot be fit because its fitting region extends beyond the star cutout image. [photutils.psf.epsf]
# WARNING: The star at (6.0, 9.0) cannot be fit because its fitting region extends beyond the star cutout image. [photutils.psf.epsf]
# WARNING: The star at (0.0, 2.0) cannot be fit because its fitting region extends beyond the star cutout image. [photutils.psf.epsf]
# PROGRESS: iteration 10 (of max 10) [1.7 s/iter]
# WARNING: The star at (8.0, 9.0) cannot be fit because its fitting region extends beyond the star cutout image. [photutils.psf.epsf]
# WARNING: The star at (5.0, 0.0) cannot be fit because its fitting region extends beyond the star cutout image. [photutils.psf.epsf]
# WARNING: The star at (0.0, 3.0) cannot be fit because its fitting region extends beyond the star cutout image. [photutils.psf.epsf]
# WARNING: The star at (0.0, 5.0) cannot be fit because its fitting region extends beyond the star cutout image. [photutils.psf.epsf]
# WARNING: The star at (8.0, 7.0) cannot be fit because its fitting region extends beyond the star cutout image. [photutils.psf.epsf]
# WARNING: The star at (6.0, 7.0) cannot be fit because its fitting region extends beyond the star cutout image. [photutils.psf.epsf]
# WARNING: The star at (3.0, 9.0) cannot be fit because its fitting region extends beyond the star cutout image. [photutils.psf.epsf]
# WARNING: The star at (8.0, 6.0) cannot be fit because its fitting region extends beyond the star cutout image. [photutils.psf.epsf]
# WARNING: The star at (5.0, 5.0) cannot be fit because its fitting region extends beyond the star cutout image. [photutils.psf.epsf]
# WARNING: The star at (4.0, 1.0) cannot be fit because its fitting region extends beyond the star cutout image. [photutils.psf.epsf]
# WARNING: The star at (2.0, 10.0) cannot be fit because its fitting region extends beyond the star cutout image. [photutils.psf.epsf]
# WARNING: The star at (9.0, 4.0) cannot be fit because its fitting region extends beyond the star cutout image. [photutils.psf.epsf]
# WARNING: The star at (0.0, 1.0) cannot be fit because its fitting region extends beyond the star cutout image. [photutils.psf.epsf]
# WARNING: The star at (0.0, 0.0) cannot be fit because its fitting region extends beyond the star cutout image. [photutils.psf.epsf]
# WARNING: The star at (3.0, 0.0) cannot be fit because its fitting region extends beyond the star cutout image. [photutils.psf.epsf]
# WARNING: The star at (9.0, 3.0) cannot be fit because its fitting region extends beyond the star cutout image. [photutils.psf.epsf]
# WARNING: The star at (4.0, 5.0) cannot be fit because its fitting region extends beyond the star cutout image. [photutils.psf.epsf]
# WARNING: The star at (9.0, 8.0) cannot be fit because its fitting region extends beyond the star cutout image. [photutils.psf.epsf]
# WARNING: The star at (6.0, 1.0) cannot be fit because its fitting region extends beyond the star cutout image. [photutils.psf.epsf]
# WARNING: The star at (6.0, 9.0) cannot be fit because its fitting region extends beyond the star cutout image. [photutils.psf.epsf]
# WARNING: The star at (0.0, 2.0) cannot be fit because its fitting region extends beyond the star cutout image. [photutils.psf.epsf]

# %%
import matplotlib.pyplot as plt

# %%
pickle.dump(epsf, open( "data/epsf29.p", "wb" ))

# %%
norm = simple_norm(epsf.data, 'log', percent=99.)
plt.imshow(epsf.data[6:50,87:133], norm=norm, origin='lower', cmap='viridis')
plt.colorbar()

# %%
epsfb
